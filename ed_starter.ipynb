# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import requests
import json
from austin_api import token, token_secret

intakes_url = "https://data.austintexas.gov/resource/wter-evkm.json"
outcomes_url = "https://data.austintexas.gov/resource/9t4d-g238.json"

# %%
def get_animal_info(url, token, **attr):
    """ Takes api url and a list of search terms and their 
        values to be passed as params into the request"""
    payload = {
        **attr,
        "$$app_token": token,
    }
    
    r = requests.get(url, params=payload)
    
    if r.status_code == 200:
        return r.json()
    else:
        return None

# %%
dog_request = get_animal_info(
    intakes_url, 
    token,
    animal_type = "Dog", 
    sex_upon_intake ="Intact Male", 
    )

dog_request
# Out:
# [{'animal_id': 'A811676',
#   'datetime': '2020-01-07T16:01:00.000',
#   'datetime2': '2020-01-07T16:01:00.000',
#   'found_location': 'Cameron And Camino La Costa in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Brown/Tan'},
#  {'animal_id': 'A811678',
#   'datetime': '2020-01-07T15:36:00.000',
#   'datetime2': '2020-01-07T15:36:00.000',
#   'found_location': '2953 Bridekirk Drive in Round Rock (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 months',
#   'breed': 'Maltese/Miniature Poodle',
#   'color': 'Black/White'},
#  {'animal_id': 'A811679',
#   'datetime': '2020-01-07T16:42:00.000',
#   'datetime2': '2020-01-07T16:42:00.000',
#   'found_location': '14908 Shell Hill Cove in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Rottweiler/Great Pyrenees',
#   'color': 'Brown/Gray'},
#  {'animal_id': 'A811680',
#   'datetime': '2020-01-07T16:42:00.000',
#   'datetime2': '2020-01-07T16:42:00.000',
#   'found_location': '14908 Shell Hill Cove in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Rottweiler',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A811677',
#   'datetime': '2020-01-07T15:36:00.000',
#   'datetime2': '2020-01-07T15:36:00.000',
#   'found_location': '2953 Bridekirk Drive in Round Rock (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Maltese/Miniature Poodle',
#   'color': 'White/Black'},
#  {'animal_id': 'A811657',
#   'datetime': '2020-01-07T11:42:00.000',
#   'datetime2': '2020-01-07T11:42:00.000',
#   'found_location': 'Braker Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Blue Merle'},
#  {'animal_id': 'A811661',
#   'datetime': '2020-01-07T12:56:00.000',
#   'datetime2': '2020-01-07T12:56:00.000',
#   'found_location': '12010 Shady Springs Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 months',
#   'breed': 'Pit Bull',
#   'color': 'Black Brindle'},
#  {'animal_id': 'A811666',
#   'datetime': '2020-01-07T13:28:00.000',
#   'datetime2': '2020-01-07T13:28:00.000',
#   'found_location': '5304 Blue Bluff in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'German Shepherd Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A811012',
#   'name': '*Toyota',
#   'datetime': '2019-12-26T13:11:00.000',
#   'datetime2': '2019-12-26T13:11:00.000',
#   'found_location': '1156 W Cesar Chavez in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull',
#   'color': 'Blue'},
#  {'animal_id': 'A811652',
#   'datetime': '2020-01-07T11:15:00.000',
#   'datetime2': '2020-01-07T11:15:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'German Shepherd',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A811654',
#   'name': 'Yogy',
#   'datetime': '2020-01-07T11:31:00.000',
#   'datetime2': '2020-01-07T11:31:00.000',
#   'found_location': '13021 Dessau Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 years',
#   'breed': 'Bichon Frise',
#   'color': 'White'},
#  {'animal_id': 'A811655',
#   'datetime': '2020-01-07T11:24:00.000',
#   'datetime2': '2020-01-07T11:24:00.000',
#   'found_location': '1916 Tillery Street in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 months',
#   'breed': 'Boerboel',
#   'color': 'Brown'},
#  {'animal_id': 'A811646',
#   'name': 'Pablo',
#   'datetime': '2020-01-07T10:52:00.000',
#   'datetime2': '2020-01-07T10:52:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Behavior',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Longhair',
#   'color': 'Tan/White'},
#  {'animal_id': 'A811345',
#   'name': 'Archie',
#   'datetime': '2020-01-02T11:56:00.000',
#   'datetime2': '2020-01-02T11:56:00.000',
#   'found_location': '4106 N Lamar Blvd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 months',
#   'breed': 'Labrador Retriever',
#   'color': 'White/Black'},
#  {'animal_id': 'A811629',
#   'datetime': '2020-01-06T17:49:00.000',
#   'datetime2': '2020-01-06T17:49:00.000',
#   'found_location': '7018 Hillcroft Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'American Staffordshire Terrier',
#   'color': 'Brown/White'},
#  {'animal_id': 'A811624',
#   'datetime': '2020-01-06T17:06:00.000',
#   'datetime2': '2020-01-06T17:06:00.000',
#   'found_location': '2504 Huntwick Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Border Collie Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A749473',
#   'name': 'Boss',
#   'datetime': '2020-01-06T17:32:00.000',
#   'datetime2': '2020-01-06T17:32:00.000',
#   'found_location': '1006 E Yager Ln in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '11 years',
#   'breed': 'Staffordshire Mix',
#   'color': 'White/Tan'},
#  {'animal_id': 'A811336',
#   'name': 'Frankie',
#   'datetime': '2020-01-02T11:16:00.000',
#   'datetime2': '2020-01-02T11:16:00.000',
#   'found_location': '13350 Old Kimbro Road in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black/Tan'},
#  {'animal_id': 'A811621',
#   'datetime': '2020-01-06T16:02:00.000',
#   'datetime2': '2020-01-06T16:02:00.000',
#   'found_location': 'Mesa Drive And Escondido Drive in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '10 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'White/Black'},
#  {'animal_id': 'A811607',
#   'name': 'Hunter',
#   'datetime': '2020-01-06T14:20:00.000',
#   'datetime2': '2020-01-06T14:20:00.000',
#   'found_location': '310 East Rundberg Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 years',
#   'breed': 'German Shepherd',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A811610',
#   'name': 'Ned',
#   'datetime': '2020-01-06T14:35:00.000',
#   'datetime2': '2020-01-06T14:35:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 months',
#   'breed': 'Labrador Retriever/Australian Shepherd',
#   'color': 'Tricolor'},
#  {'animal_id': 'A799100',
#   'name': 'Oso',
#   'datetime': '2020-01-06T14:20:00.000',
#   'datetime2': '2020-01-06T14:20:00.000',
#   'found_location': '7707 S Ih 35 Svcrd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 years',
#   'breed': 'St. Bernard Smooth Coat',
#   'color': 'Tan/Tricolor'},
#  {'animal_id': 'A811606',
#   'datetime': '2020-01-06T13:47:00.000',
#   'datetime2': '2020-01-06T13:47:00.000',
#   'found_location': '5600 Springdale Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black'},
#  {'animal_id': 'A811555',
#   'name': '*Eros',
#   'datetime': '2020-01-05T15:57:00.000',
#   'datetime2': '2020-01-05T15:57:00.000',
#   'found_location': 'Fm 973 And Us 183 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Brown/Tan'},
#  {'animal_id': 'A811554',
#   'name': '*Cupid',
#   'datetime': '2020-01-05T15:57:00.000',
#   'datetime2': '2020-01-05T15:57:00.000',
#   'found_location': 'Fm 973 And Us 183 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A811592',
#   'datetime': '2020-01-06T11:54:00.000',
#   'datetime2': '2020-01-06T11:54:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 days',
#   'breed': 'Dachshund Mix',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A811593',
#   'datetime': '2020-01-06T11:54:00.000',
#   'datetime2': '2020-01-06T11:54:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 days',
#   'breed': 'Dachshund Mix',
#   'color': 'Chocolate/Tan'},
#  {'animal_id': 'A811587',
#   'datetime': '2020-01-06T11:33:00.000',
#   'datetime2': '2020-01-06T11:33:00.000',
#   'found_location': 'Leaning Willow Drive And Pine Knoll Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Cream/White'},
#  {'animal_id': 'A811595',
#   'datetime': '2020-01-06T11:54:00.000',
#   'datetime2': '2020-01-06T11:54:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 days',
#   'breed': 'Dachshund Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A807589',
#   'name': 'Fitzgerald',
#   'datetime': '2019-10-27T11:13:00.000',
#   'datetime2': '2019-10-27T11:13:00.000',
#   'found_location': 'Jones Road in Manor (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Soft Coated Wheaten Terrier Mix',
#   'color': 'Silver/Black'},
#  {'animal_id': 'A811335',
#   'name': '*Manfred',
#   'datetime': '2020-01-02T10:30:00.000',
#   'datetime2': '2020-01-02T10:30:00.000',
#   'found_location': '204 Meadow Lea Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'German Shepherd',
#   'color': 'Black/Tan'},
#  {'animal_id': 'A811591',
#   'datetime': '2020-01-06T11:54:00.000',
#   'datetime2': '2020-01-06T11:54:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 days',
#   'breed': 'Dachshund Mix',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A811604',
#   'datetime': '2020-01-06T11:54:00.000',
#   'datetime2': '2020-01-06T11:54:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 days',
#   'breed': 'Dachshund',
#   'color': 'Brown/White'},
#  {'animal_id': 'A811362',
#   'name': '*Janko',
#   'datetime': '2020-01-02T13:04:00.000',
#   'datetime2': '2020-01-02T13:04:00.000',
#   'found_location': '8625 Fireside Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Alaskan Husky',
#   'color': 'Brown/Tan'},
#  {'animal_id': 'A759877',
#   'name': 'Nova',
#   'datetime': '2020-01-06T10:14:00.000',
#   'datetime2': '2020-01-06T10:14:00.000',
#   'found_location': '2801 West Wells Branch Parkway in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White'},
#  {'animal_id': 'A765518',
#   'name': 'Doc',
#   'datetime': '2018-01-21T19:21:00.000',
#   'datetime2': '2018-01-21T19:21:00.000',
#   'found_location': 'Slaughter And Onion Creek in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Akita/Labrador Retriever',
#   'color': 'Buff'},
#  {'animal_id': 'A811388',
#   'datetime': '2020-01-02T16:03:00.000',
#   'datetime2': '2020-01-02T16:03:00.000',
#   'found_location': '7005 Blessing Avenue in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'German Shepherd',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A811567',
#   'name': 'Ford',
#   'datetime': '2020-01-06T07:18:00.000',
#   'datetime2': '2020-01-06T07:18:00.000',
#   'found_location': '3710 West Howard Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Rhod Ridgeback',
#   'color': 'Red'},
#  {'animal_id': 'A811265',
#   'datetime': '2019-12-31T12:44:00.000',
#   'datetime2': '2019-12-31T12:44:00.000',
#   'found_location': '1088 Park Plz in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 years',
#   'breed': 'Miniature Poodle Mix',
#   'color': 'White'},
#  {'animal_id': 'A806768',
#   'name': 'Texas',
#   'datetime': '2019-10-15T12:28:00.000',
#   'datetime2': '2019-10-15T12:28:00.000',
#   'found_location': 'Lockwood Road And Taylor Lane in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Black Mouth Cur',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A685434',
#   'name': '*Cowboybebop',
#   'datetime': '2014-08-07T13:11:00.000',
#   'datetime2': '2014-08-07T13:11:00.000',
#   'found_location': '7020 Grand Canyon Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '7 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black'},
#  {'animal_id': 'A811551',
#   'datetime': '2020-01-05T15:49:00.000',
#   'datetime2': '2020-01-05T15:49:00.000',
#   'found_location': '3503 Webberville Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A808923',
#   'name': '*Cowboy',
#   'datetime': '2019-11-16T11:01:00.000',
#   'datetime2': '2019-11-16T11:01:00.000',
#   'found_location': 'Travis (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Australian Cattle Dog',
#   'color': 'Black/White'},
#  {'animal_id': 'A811494',
#   'datetime': '2020-01-04T15:08:00.000',
#   'datetime2': '2020-01-04T15:08:00.000',
#   'found_location': '9008 Briardale Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Akita',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A811552',
#   'datetime': '2020-01-05T15:49:00.000',
#   'datetime2': '2020-01-05T15:49:00.000',
#   'found_location': '3503 Webberville Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black'},
#  {'animal_id': 'A810944',
#   'name': 'Toby',
#   'datetime': '2019-12-23T12:55:00.000',
#   'datetime2': '2019-12-23T12:55:00.000',
#   'found_location': 'Ralph Ablanedo Drive And Peaceful Hill Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'German Shepherd/Akita',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A811543',
#   'datetime': '2020-01-05T14:18:00.000',
#   'datetime2': '2020-01-05T14:18:00.000',
#   'found_location': '7601 E Ben White Blvd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Australian Kelpie Mix',
#   'color': 'Black'},
#  {'animal_id': 'A811514',
#   'datetime': '2020-01-04T19:07:00.000',
#   'datetime2': '2020-01-04T19:07:00.000',
#   'found_location': 'Guadalupe Street And Northcross in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair/Dachshund',
#   'color': 'Tan/White'},
#  {'animal_id': 'A811531',
#   'datetime': '2020-01-05T12:32:00.000',
#   'datetime2': '2020-01-05T12:32:00.000',
#   'found_location': '9400 North Ih 35 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A811195',
#   'name': '*Lawerance',
#   'datetime': '2019-12-29T17:45:00.000',
#   'datetime2': '2019-12-29T17:45:00.000',
#   'found_location': '2300 West Ben White Boulevard in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 years',
#   'breed': 'German Shepherd',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A811529',
#   'name': 'Chico',
#   'datetime': '2020-01-05T11:39:00.000',
#   'datetime2': '2020-01-05T11:39:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A809754',
#   'name': 'Snow',
#   'datetime': '2020-01-03T14:55:00.000',
#   'datetime2': '2020-01-03T14:55:00.000',
#   'found_location': '2405 Dove Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Pit Bull Mix',
#   'color': 'White'},
#  {'animal_id': 'A811482',
#   'name': 'Blue',
#   'datetime': '2020-01-04T13:09:00.000',
#   'datetime2': '2020-01-04T13:09:00.000',
#   'found_location': 'Plainview And Fallenash in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Pit Bull',
#   'color': 'Blue/White'},
#  {'animal_id': 'A811527',
#   'datetime': '2020-01-05T11:30:00.000',
#   'datetime2': '2020-01-05T11:30:00.000',
#   'found_location': '1230 38 1/2 Street in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Red/White'},
#  {'animal_id': 'A811450',
#   'name': 'Cody',
#   'datetime': '2020-01-03T16:58:00.000',
#   'datetime2': '2020-01-03T16:58:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A811464',
#   'datetime': '2020-01-04T11:58:00.000',
#   'datetime2': '2020-01-04T11:58:00.000',
#   'found_location': '10000 Logistics Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A811525',
#   'name': 'Riley',
#   'datetime': '2020-01-05T11:11:00.000',
#   'datetime2': '2020-01-05T11:11:00.000',
#   'found_location': '6507 Circle S Road in Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Brown/White'},
#  {'animal_id': 'A811489',
#   'datetime': '2020-01-04T13:58:00.000',
#   'datetime2': '2020-01-04T13:58:00.000',
#   'found_location': '14601 Plover Place in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Labrador Retriever',
#   'color': 'Brown/White'},
#  {'animal_id': 'A811011',
#   'name': '*Dually',
#   'datetime': '2019-12-26T13:11:00.000',
#   'datetime2': '2019-12-26T13:11:00.000',
#   'found_location': '1156 W Cesar Chavez in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull',
#   'color': 'Blue/White'},
#  {'animal_id': 'A811486',
#   'name': 'Zues',
#   'datetime': '2020-01-04T13:45:00.000',
#   'datetime2': '2020-01-04T13:45:00.000',
#   'found_location': '12501 Deer Falls Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'American Pit Bull Terrier',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A811507',
#   'datetime': '2020-01-04T17:00:00.000',
#   'datetime2': '2020-01-04T17:00:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Wire Hair Fox Terrier',
#   'color': 'Black/White'},
#  {'animal_id': 'A811490',
#   'datetime': '2020-01-04T14:09:00.000',
#   'datetime2': '2020-01-04T14:09:00.000',
#   'found_location': 'Nuckols Crossing And East Stassney in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Yellow'},
#  {'animal_id': 'A811505',
#   'datetime': '2020-01-04T16:36:00.000',
#   'datetime2': '2020-01-04T16:36:00.000',
#   'found_location': 'Parsons Road And Littig Road in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'White/Tan'},
#  {'animal_id': 'A811466',
#   'datetime': '2020-01-04T12:12:00.000',
#   'datetime2': '2020-01-04T12:12:00.000',
#   'found_location': '12901 North Ih 35 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Jack Russell Terrier/Cairn Terrier',
#   'color': 'White'},
#  {'animal_id': 'A811465',
#   'datetime': '2020-01-04T12:04:00.000',
#   'datetime2': '2020-01-04T12:04:00.000',
#   'found_location': '9400 North  Lamar in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'White/Black'},
#  {'animal_id': 'A811487',
#   'datetime': '2020-01-04T13:54:00.000',
#   'datetime2': '2020-01-04T13:54:00.000',
#   'found_location': '1007 East Rundberg in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Staffordshire Mix',
#   'color': 'Blue Tiger/White'},
#  {'animal_id': 'A770032',
#   'name': 'Fritz',
#   'datetime': '2018-04-14T13:26:00.000',
#   'datetime2': '2018-04-14T13:26:00.000',
#   'found_location': 'Green Meadows Drive in Pflugerville (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 years',
#   'breed': 'Miniature Schnauzer',
#   'color': 'Gray/Black'},
#  {'animal_id': 'A802856',
#   'name': 'Rico',
#   'datetime': '2019-08-23T19:12:00.000',
#   'datetime2': '2019-08-23T19:12:00.000',
#   'found_location': '403 West Crestland Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Dachshund Mix',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A788293',
#   'name': 'Kovu',
#   'datetime': '2020-01-03T07:54:00.000',
#   'datetime2': '2020-01-03T07:54:00.000',
#   'found_location': '1401 E Rundberg Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Shih Tzu Mix',
#   'color': 'Sable'},
#  {'animal_id': 'A810704',
#   'name': '*Dasher',
#   'datetime': '2019-12-18T13:02:00.000',
#   'datetime2': '2019-12-18T13:02:00.000',
#   'found_location': 'Pearce Lane And Pimilco Drive in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever/Great Pyrenees',
#   'color': 'Cream'},
#  {'animal_id': 'A810705',
#   'name': '*Comet',
#   'datetime': '2019-12-18T13:02:00.000',
#   'datetime2': '2019-12-18T13:02:00.000',
#   'found_location': 'Pearce Lane And Pimilco Drive in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever/Great Pyrenees',
#   'color': 'Cream/White'},
#  {'animal_id': 'A811387',
#   'name': 'Rocker',
#   'datetime': '2020-01-02T15:57:00.000',
#   'datetime2': '2020-01-02T15:57:00.000',
#   'found_location': 'Parmer And Dessau Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A811288',
#   'datetime': '2019-12-31T14:53:00.000',
#   'datetime2': '2019-12-31T14:53:00.000',
#   'found_location': '6911 Wentworth Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 days',
#   'breed': 'Labrador Retriever',
#   'color': 'Brown'},
#  {'animal_id': 'A809599',
#   'name': 'Milo',
#   'datetime': '2019-11-27T13:51:00.000',
#   'datetime2': '2019-11-27T13:51:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '7 months',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'White/Brown'},
#  {'animal_id': 'A811062',
#   'name': '*Turkey',
#   'datetime': '2019-12-27T11:21:00.000',
#   'datetime2': '2019-12-27T11:21:00.000',
#   'found_location': '2453 Bastrop Highway in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'German Shepherd',
#   'color': 'Black/Tricolor'},
#  {'animal_id': 'A810935',
#   'name': '*Earl Grey',
#   'datetime': '2019-12-23T11:31:00.000',
#   'datetime2': '2019-12-23T11:31:00.000',
#   'found_location': '12200 Fm 969 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 months',
#   'breed': 'Border Collie/Anatol Shepherd',
#   'color': 'White/Black'},
#  {'animal_id': 'A811022',
#   'name': '*Sailor Boy',
#   'datetime': '2019-12-26T15:04:00.000',
#   'datetime2': '2019-12-26T15:04:00.000',
#   'found_location': 'Rutherford B Hayes St in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Norwegian Elkhound/Alaskan Husky',
#   'color': 'Tan/Black'},
#  {'animal_id': 'A801287',
#   'name': 'Lucky',
#   'datetime': '2019-08-02T12:57:00.000',
#   'datetime2': '2019-08-02T12:57:00.000',
#   'found_location': '10507 Mellow Meadow in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Siberian Husky',
#   'color': 'Tricolor/Black'},
#  {'animal_id': 'A811173',
#   'datetime': '2019-12-29T13:10:00.000',
#   'datetime2': '2019-12-29T13:10:00.000',
#   'found_location': '7605 Colton Bluff Springs Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 months',
#   'breed': 'Golden Retriever',
#   'color': 'Red'},
#  {'animal_id': 'A811174',
#   'datetime': '2019-12-29T13:10:00.000',
#   'datetime2': '2019-12-29T13:10:00.000',
#   'found_location': '7605 Colton Bluff Springs Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 months',
#   'breed': 'Golden Retriever',
#   'color': 'Red/White'},
#  {'animal_id': 'A811171',
#   'datetime': '2019-12-29T13:19:00.000',
#   'datetime2': '2019-12-29T13:19:00.000',
#   'found_location': '1010 Turtle Creek Boulevard in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 months',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'Tan'},
#  {'animal_id': 'A811164',
#   'datetime': '2019-12-29T11:50:00.000',
#   'datetime2': '2019-12-29T11:50:00.000',
#   'found_location': '11304 Robert Wooding Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair/Dachshund',
#   'color': 'Red'},
#  {'animal_id': 'A810245',
#   'name': 'Zookie',
#   'datetime': '2019-12-09T17:33:00.000',
#   'datetime2': '2019-12-09T17:33:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Kuvasz/Labrador Retriever',
#   'color': 'White'},
#  {'animal_id': 'A806805',
#   'name': '*Billy',
#   'datetime': '2019-10-15T17:52:00.000',
#   'datetime2': '2019-10-15T17:52:00.000',
#   'found_location': '1907 Hearthstone Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Pug/Pit Bull',
#   'color': 'Red/White'},
#  {'animal_id': 'A811140',
#   'datetime': '2019-12-28T18:04:00.000',
#   'datetime2': '2019-12-28T18:04:00.000',
#   'found_location': '3500 Banda Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'Tricolor'},
#  {'animal_id': 'A811133',
#   'datetime': '2019-12-28T16:10:00.000',
#   'datetime2': '2019-12-28T16:10:00.000',
#   'found_location': 'Macmora And Topperwein in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Miniature Schnauzer',
#   'color': 'Gray/Black'},
#  {'animal_id': 'A811132',
#   'datetime': '2019-12-28T17:15:00.000',
#   'datetime2': '2019-12-28T17:15:00.000',
#   'found_location': '1600 Tickford Drive in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Norfolk Terrier',
#   'color': 'Tricolor'},
#  {'animal_id': 'A811067',
#   'datetime': '2019-12-27T13:00:00.000',
#   'datetime2': '2019-12-27T13:00:00.000',
#   'found_location': '7601 Daffan Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 years',
#   'breed': 'Chinese Crested/Chihuahua Shorthair',
#   'color': 'Black/White'},
#  {'animal_id': 'A807698',
#   'name': 'Colmillo Blanco',
#   'datetime': '2019-12-28T15:54:00.000',
#   'datetime2': '2019-12-28T15:54:00.000',
#   'found_location': '7310 East Riverside Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 months',
#   'breed': 'Siberian Husky Mix',
#   'color': 'White'},
#  {'animal_id': 'A811014',
#   'name': 'Rocko',
#   'datetime': '2019-12-26T13:54:00.000',
#   'datetime2': '2019-12-26T13:54:00.000',
#   'found_location': '20901 Windham Drive in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Boxer',
#   'color': 'Tan/White'},
#  {'animal_id': 'A798994',
#   'name': '*Chance',
#   'datetime': '2019-07-02T20:08:00.000',
#   'datetime2': '2019-07-02T20:08:00.000',
#   'found_location': '9900 Horizon Ln in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'German Shepherd',
#   'color': 'Brown/White'},
#  {'animal_id': 'A810846',
#   'name': 'Biggie Smalls',
#   'datetime': '2019-12-21T15:17:00.000',
#   'datetime2': '2019-12-21T15:17:00.000',
#   'found_location': '5304 Blue Buff Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'White'},
#  {'animal_id': 'A811102',
#   'datetime': '2019-12-27T19:02:00.000',
#   'datetime2': '2019-12-27T19:02:00.000',
#   'found_location': '910 Water Lane in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Australian Cattle Dog',
#   'color': 'Tan/Red Merle'},
#  {'animal_id': 'A765292',
#   'name': '*Huxley',
#   'datetime': '2018-01-17T11:14:00.000',
#   'datetime2': '2018-01-17T11:14:00.000',
#   'found_location': '1300 South Plesant Valley Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 months',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A810774',
#   'name': '*Gunner',
#   'datetime': '2019-12-19T18:42:00.000',
#   'datetime2': '2019-12-19T18:42:00.000',
#   'found_location': 'Merrilltown And Noya Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A800928',
#   'name': 'Scoot',
#   'datetime': '2019-07-29T10:59:00.000',
#   'datetime2': '2019-07-29T10:59:00.000',
#   'found_location': '12900 North I35 Service Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 months',
#   'breed': 'Border Terrier Mix',
#   'color': 'Tan/Black'},
#  {'animal_id': 'A811068',
#   'datetime': '2019-12-27T13:00:00.000',
#   'datetime2': '2019-12-27T13:00:00.000',
#   'found_location': '7601 Daffan Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Chinese Crested/Chihuahua Shorthair',
#   'color': 'White/Brown'},
#  {'animal_id': 'A810687',
#   'name': '*Steven',
#   'datetime': '2019-12-18T12:13:00.000',
#   'datetime2': '2019-12-18T12:13:00.000',
#   'found_location': '3112 East Cesar Chavez Street in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Rottweiler Mix',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A810695',
#   'name': 'Pookie',
#   'datetime': '2019-12-18T12:47:00.000',
#   'datetime2': '2019-12-18T12:47:00.000',
#   'found_location': '9200 North Plaza in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Wire Hair Fox Terrier',
#   'color': 'Brown'},
#  {'animal_id': 'A776565',
#   'name': 'Max',
#   'datetime': '2018-07-18T12:22:00.000',
#   'datetime2': '2018-07-18T12:22:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Great Pyrenees',
#   'color': 'White/White'},
#  {'animal_id': 'A784712',
#   'name': 'Toby',
#   'datetime': '2018-11-19T12:20:00.000',
#   'datetime2': '2018-11-19T12:20:00.000',
#   'found_location': '2801 Palomino Trail in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever/Border Collie',
#   'color': 'Black/White'},
#  {'animal_id': 'A811063',
#   'datetime': '2019-12-27T11:53:00.000',
#   'datetime2': '2019-12-27T11:53:00.000',
#   'found_location': '1916 Tillery Street in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Pit Bull',
#   'color': 'Blue/White'},
#  {'animal_id': 'A810826',
#   'name': '*Phantom',
#   'datetime': '2019-12-21T12:21:00.000',
#   'datetime2': '2019-12-21T12:21:00.000',
#   'found_location': 'Manchester Circle And Suburban Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever',
#   'color': 'Black'},
#  {'animal_id': 'A810805',
#   'name': '*Slim Shady',
#   'datetime': '2019-12-20T18:35:00.000',
#   'datetime2': '2019-12-20T18:35:00.000',
#   'found_location': '10001 Burleson Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Beagle Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A810209',
#   'datetime': '2019-12-09T10:44:00.000',
#   'datetime2': '2019-12-09T10:44:00.000',
#   'found_location': '8200 Research Boulevard in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'Pit Bull Mix',
#   'color': 'Sable/White'},
#  {'animal_id': 'A810214',
#   'datetime': '2019-12-09T10:44:00.000',
#   'datetime2': '2019-12-09T10:44:00.000',
#   'found_location': '8200 Research Boulevard in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue Merle'},
#  {'animal_id': 'A810049',
#   'name': '*Kade',
#   'datetime': '2019-12-06T11:40:00.000',
#   'datetime2': '2019-12-06T11:40:00.000',
#   'found_location': '8112 Bestride Bend in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Siberian Husky/Akita',
#   'color': 'Sable'},
#  {'animal_id': 'A810752',
#   'name': '*Malcolm',
#   'datetime': '2019-12-19T13:12:00.000',
#   'datetime2': '2019-12-19T13:12:00.000',
#   'found_location': '12138 North Lamar Boulevard in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Labrador Retriever',
#   'color': 'Black/White'},
#  {'animal_id': 'A810809',
#   'name': 'Scott',
#   'datetime': '2019-12-20T18:55:00.000',
#   'datetime2': '2019-12-20T18:55:00.000',
#   'found_location': 'William Cannon And Ih35 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Australian Cattle Dog Mix',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A811025',
#   'datetime': '2019-12-26T15:56:00.000',
#   'datetime2': '2019-12-26T15:56:00.000',
#   'found_location': 'Bratton And Shoreline in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Plott Hound Mix',
#   'color': 'Brown Brindle'},
#  {'animal_id': 'A810999',
#   'name': 'Enzo',
#   'datetime': '2019-12-26T14:38:00.000',
#   'datetime2': '2019-12-26T14:38:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 years',
#   'breed': 'Australian Shepherd/Great Pyrenees',
#   'color': 'White/Tan'},
#  {'animal_id': 'A810880',
#   'name': '*Napoleon',
#   'datetime': '2019-12-22T11:17:00.000',
#   'datetime2': '2019-12-22T11:17:00.000',
#   'found_location': '9420 North Interstate Highway 35 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pembroke Welsh Corgi Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A810206',
#   'datetime': '2019-12-09T10:44:00.000',
#   'datetime2': '2019-12-09T10:44:00.000',
#   'found_location': '8200 Research Boulevard in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'Pit Bull Mix',
#   'color': 'Sable'},
#  {'animal_id': 'A810950',
#   'name': 'Rockie',
#   'datetime': '2019-12-23T14:17:00.000',
#   'datetime2': '2019-12-23T14:17:00.000',
#   'found_location': 'Pflugerville (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Boxer',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A809579',
#   'name': 'Ice',
#   'datetime': '2019-11-27T11:06:00.000',
#   'datetime2': '2019-11-27T11:06:00.000',
#   'found_location': 'Bolm Road And Airport Boulevard in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Siberian Husky',
#   'color': 'White/Black'},
#  {'animal_id': 'A809388',
#   'name': '*Remy',
#   'datetime': '2019-11-23T15:24:00.000',
#   'datetime2': '2019-11-23T15:24:00.000',
#   'found_location': '7800 Johnny Morris Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '7 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Brown'},
#  {'animal_id': 'A810974',
#   'name': 'Jamo',
#   'datetime': '2019-12-23T17:14:00.000',
#   'datetime2': '2019-12-23T17:14:00.000',
#   'found_location': '1200 Cometa in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull',
#   'color': 'Gray/White'},
#  {'animal_id': 'A810981',
#   'datetime': '2019-12-23T18:03:00.000',
#   'datetime2': '2019-12-23T18:03:00.000',
#   'found_location': 'Little Elm Park And Blue Quail Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull',
#   'color': 'Black Brindle'},
#  {'animal_id': 'A810946',
#   'name': 'Stuart',
#   'datetime': '2019-12-23T13:35:00.000',
#   'datetime2': '2019-12-23T13:35:00.000',
#   'found_location': 'Gregg Lane And Fuchs Grove Road in Manor (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair/Pug',
#   'color': 'Brown'},
#  {'animal_id': 'A810968',
#   'datetime': '2019-12-23T16:23:00.000',
#   'datetime2': '2019-12-23T16:23:00.000',
#   'found_location': '8957 Elroy Road in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Labrador Retriever',
#   'color': 'Black/White'},
#  {'animal_id': 'A666770',
#   'name': 'Josh',
#   'datetime': '2013-11-07T07:46:00.000',
#   'datetime2': '2013-11-07T07:46:00.000',
#   'found_location': 'Fitzhugh Rd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Siberian Husky Mix',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A810947',
#   'name': 'Gordo',
#   'datetime': '2019-12-23T13:30:00.000',
#   'datetime2': '2019-12-23T13:30:00.000',
#   'found_location': 'Maxwell Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Shih Tzu',
#   'color': 'Tricolor'},
#  {'animal_id': 'A776284',
#   'name': 'Jack',
#   'datetime': '2018-07-11T10:21:00.000',
#   'datetime2': '2018-07-11T10:21:00.000',
#   'found_location': 'Us Highway 290 And Decker Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Plott Hound/Australian Cattle Dog',
#   'color': 'White/Tan'},
#  {'animal_id': 'A810942',
#   'name': 'Muneca',
#   'datetime': '2019-12-23T12:59:00.000',
#   'datetime2': '2019-12-23T12:59:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
# ...
#   'age_upon_intake': '4 weeks',
#   'breed': 'Bloodhound Mix',
#   'color': 'Black'},
#  {'animal_id': 'A796640',
#   'name': 'Fonzi',
#   'datetime': '2019-06-03T18:23:00.000',
#   'datetime2': '2019-06-03T18:23:00.000',
#   'found_location': 'Mt Vernon And Philco in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Bloodhound Mix',
#   'color': 'Brown Brindle'},
#  {'animal_id': 'A797892',
#   'name': 'Sammy',
#   'datetime': '2019-06-19T09:40:00.000',
#   'datetime2': '2019-06-19T09:40:00.000',
#   'found_location': 'Kellam Rd & Hwy 71 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pug',
#   'color': 'Black'},
#  {'animal_id': 'A806139',
#   'name': '*Riley',
#   'datetime': '2019-10-06T11:29:00.000',
#   'datetime2': '2019-10-06T11:29:00.000',
#   'found_location': '7316 Branrust Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Beagle Mix',
#   'color': 'Brown/White'},
#  {'animal_id': 'A806437',
#   'name': '*Charming',
#   'datetime': '2019-10-10T18:55:00.000',
#   'datetime2': '2019-10-10T18:55:00.000',
#   'found_location': '9300 South Ih 35 Frontage Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Alaskan Husky/German Shepherd',
#   'color': 'Brown/Tricolor'},
#  {'animal_id': 'A772176',
#   'name': 'Scrappy',
#   'datetime': '2018-05-15T16:37:00.000',
#   'datetime2': '2018-05-15T16:37:00.000',
#   'found_location': '1137 Gunter in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 months',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A806727',
#   'datetime': '2019-10-14T18:16:00.000',
#   'datetime2': '2019-10-14T18:16:00.000',
#   'found_location': '183 And Payton Gin in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Chihuahua Longhair Mix',
#   'color': 'Chocolate/White'},
#  {'animal_id': 'A806646',
#   'name': 'Mateo',
#   'datetime': '2019-10-14T15:56:00.000',
#   'datetime2': '2019-10-14T15:56:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull',
#   'color': 'Black'},
#  {'animal_id': 'A803386',
#   'name': '*Buddy',
#   'datetime': '2019-08-31T13:31:00.000',
#   'datetime2': '2019-08-31T13:31:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'German Shepherd/Australian Kelpie',
#   'color': 'White/Tricolor'},
#  {'animal_id': 'A803382',
#   'datetime': '2019-08-31T13:31:00.000',
#   'datetime2': '2019-08-31T13:31:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'German Shepherd/Australian Kelpie',
#   'color': 'Buff'},
#  {'animal_id': 'A803384',
#   'datetime': '2019-08-31T13:31:00.000',
#   'datetime2': '2019-08-31T13:31:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'German Shepherd/Australian Kelpie',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A803383',
#   'datetime': '2019-08-31T13:31:00.000',
#   'datetime2': '2019-08-31T13:31:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'German Shepherd/Australian Kelpie',
#   'color': 'White/Black'},
#  {'animal_id': 'A806328',
#   'name': '*Benji',
#   'datetime': '2019-10-08T17:19:00.000',
#   'datetime2': '2019-10-08T17:19:00.000',
#   'found_location': '11000 N Ih 35 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Airedale Terrier Mix',
#   'color': 'Tan/Black'},
#  {'animal_id': 'A803381',
#   'name': '*Rosco',
#   'datetime': '2019-08-31T13:31:00.000',
#   'datetime2': '2019-08-31T13:31:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'German Shepherd/Australian Kelpie',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A806689',
#   'name': 'Rio',
#   'datetime': '2019-10-14T13:38:00.000',
#   'datetime2': '2019-10-14T13:38:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '10 months',
#   'breed': 'Rottweiler',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A806671',
#   'name': 'Noble',
#   'datetime': '2019-10-14T10:55:00.000',
#   'datetime2': '2019-10-14T10:55:00.000',
#   'found_location': 'East Slaughter Lane And Brandt Road in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'German Shepherd',
#   'color': 'Black/Brown'},
#  {'animal_id': 'A805749',
#   'datetime': '2019-10-01T14:28:00.000',
#   'datetime2': '2019-10-01T14:28:00.000',
#   'found_location': '1300 Southfort Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 months',
#   'breed': 'Australian Shepherd Mix',
#   'color': 'White/Tan'},
#  {'animal_id': 'A805307',
#   'name': 'Duke',
#   'datetime': '2019-09-28T12:26:00.000',
#   'datetime2': '2019-09-28T12:26:00.000',
#   'found_location': '401 Hackberry Ln in Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Plott Hound Mix',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A806641',
#   'datetime': '2019-10-13T16:26:00.000',
#   'datetime2': '2019-10-13T16:26:00.000',
#   'found_location': '20500 Spanish Oaks Dr in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'German Shepherd Mix',
#   'color': 'Black/Tan'},
#  {'animal_id': 'A806644',
#   'datetime': '2019-10-13T16:26:00.000',
#   'datetime2': '2019-10-13T16:26:00.000',
#   'found_location': '20500 Spanish Oaks Dr in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'German Shepherd Mix',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A806643',
#   'datetime': '2019-10-13T16:26:00.000',
#   'datetime2': '2019-10-13T16:26:00.000',
#   'found_location': '20500 Spanish Oaks Dr in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'German Shepherd Mix',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A806372',
#   'name': 'Xio',
#   'datetime': '2019-10-09T16:41:00.000',
#   'datetime2': '2019-10-09T16:41:00.000',
#   'found_location': 'Blacke Manor Road in Manor (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Chihuahua Longhair',
#   'color': 'White'},
#  {'animal_id': 'A806632',
#   'datetime': '2019-10-13T15:33:00.000',
#   'datetime2': '2019-10-13T15:33:00.000',
#   'found_location': '21310 Lindeman Lane in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Alaskan Husky',
#   'color': 'Black/Gray'},
#  {'animal_id': 'A806354',
#   'name': 'Leo',
#   'datetime': '2019-10-09T13:52:00.000',
#   'datetime2': '2019-10-09T13:52:00.000',
#   'found_location': '1609 Singleton Ave in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Papillon Mix',
#   'color': 'White/Black'},
#  {'animal_id': 'A806633',
#   'datetime': '2019-10-13T15:27:00.000',
#   'datetime2': '2019-10-13T15:27:00.000',
#   'found_location': '1202 Citation Circle in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Siberian Husky/German Shepherd',
#   'color': 'Tan/Black'},
#  {'animal_id': 'A806520',
#   'datetime': '2019-10-11T23:16:00.000',
#   'datetime2': '2019-10-11T23:16:00.000',
#   'found_location': '1607 Coronado Hills Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Pit Bull/Boxer',
#   'color': 'Black/White'},
#  {'animal_id': 'A806623',
#   'datetime': '2019-10-13T13:46:00.000',
#   'datetime2': '2019-10-13T13:46:00.000',
#   'found_location': '6540 Ed Bluestein in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Shih Tzu/Miniature Poodle',
#   'color': 'Brown/White'},
#  {'animal_id': 'A806630',
#   'datetime': '2019-10-13T14:54:00.000',
#   'datetime2': '2019-10-13T14:54:00.000',
#   'found_location': '23305 Big Sandy Dr in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Great Pyrenees/Anatol Shepherd',
#   'color': 'White/Tan'},
#  {'animal_id': 'A806603',
#   'name': 'Cash',
#   'datetime': '2019-10-13T11:00:00.000',
#   'datetime2': '2019-10-13T11:00:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull',
#   'color': 'Blue/White'},
#  {'animal_id': 'A806622',
#   'name': 'Simba',
#   'datetime': '2019-10-13T13:35:00.000',
#   'datetime2': '2019-10-13T13:35:00.000',
#   'found_location': '1438 Coronado Hills Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 months',
#   'breed': 'Siberian Husky',
#   'color': 'Black/Tricolor'},
#  {'animal_id': 'A806321',
#   'name': 'Firulais',
#   'datetime': '2019-10-13T13:34:00.000',
#   'datetime2': '2019-10-13T13:34:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'White/Brown'},
#  {'animal_id': 'A795774',
#   'name': 'Neo',
#   'datetime': '2019-05-24T13:35:00.000',
#   'datetime2': '2019-05-24T13:35:00.000',
#   'found_location': 'Hunters Ridge Road And Old Lockhart Road in Creedmoor (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Border Collie Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A806538',
#   'name': 'Blue',
#   'datetime': '2019-10-12T11:44:00.000',
#   'datetime2': '2019-10-12T11:44:00.000',
#   'found_location': '8908 Capitol Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Pit Bull',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A806599',
#   'name': 'Max',
#   'datetime': '2019-10-13T10:27:00.000',
#   'datetime2': '2019-10-13T10:27:00.000',
#   'found_location': '2308 East Riverside Drive in Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'German Shepherd',
#   'color': 'Black/Tan'},
#  {'animal_id': 'A806423',
#   'datetime': '2019-10-10T16:11:00.000',
#   'datetime2': '2019-10-10T16:11:00.000',
#   'found_location': '7002 Dallas Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Scottish Terrier/Chihuahua Shorthair',
#   'color': 'Black/White'},
#  {'animal_id': 'A806325',
#   'datetime': '2019-10-08T16:46:00.000',
#   'datetime2': '2019-10-08T16:46:00.000',
#   'found_location': '1405 Ranch Road 620 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 months',
#   'breed': 'Pointer Mix',
#   'color': 'White/Brown'},
#  {'animal_id': 'A802724',
#   'name': 'Bilbo',
#   'datetime': '2019-08-21T17:09:00.000',
#   'datetime2': '2019-08-21T17:09:00.000',
#   'found_location': 'Estrellas Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Miniature Poodle Mix',
#   'color': 'Black'},
#  {'animal_id': 'A806091',
#   'name': '*Dali',
#   'datetime': '2019-10-05T13:38:00.000',
#   'datetime2': '2019-10-05T13:38:00.000',
#   'found_location': 'Lexington Drive And Highway 290 in Manor (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 months',
#   'breed': 'Australian Cattle Dog Mix',
#   'color': 'Gray/Black'},
#  {'animal_id': 'A806408',
#   'datetime': '2019-10-10T13:58:00.000',
#   'datetime2': '2019-10-10T13:58:00.000',
#   'found_location': 'Walnut Avenue And 17Th Street in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '7 months',
#   'breed': 'Beagle',
#   'color': 'Tricolor'},
#  {'animal_id': 'A806101',
#   'datetime': '2019-10-05T15:00:00.000',
#   'datetime2': '2019-10-05T15:00:00.000',
#   'found_location': '6101 Aac Highland Campus Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Dachshund/Chihuahua Shorthair',
#   'color': 'Red'},
#  {'animal_id': 'A806149',
#   'name': '*Bingley',
#   'datetime': '2019-10-06T13:24:00.000',
#   'datetime2': '2019-10-06T13:24:00.000',
#   'found_location': '6608 Branrust Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Basset Hound/American Pit Bull Terrier',
#   'color': 'Brown Tiger/White'},
#  {'animal_id': 'A800139',
#   'name': 'Iron Man',
#   'datetime': '2019-07-16T18:38:00.000',
#   'datetime2': '2019-07-16T18:38:00.000',
#   'found_location': '5313 Atascosa Drive in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Chihuahua Longhair',
#   'color': 'Black/Brown'}]

# %%
dog_request_df = pd.DataFrame(dog_request)
dog_request_df
# Out:
#     animal_id                 datetime                datetime2  \
# 0     A811676  2020-01-07T16:01:00.000  2020-01-07T16:01:00.000
# 1     A811678  2020-01-07T15:36:00.000  2020-01-07T15:36:00.000
# 2     A811679  2020-01-07T16:42:00.000  2020-01-07T16:42:00.000
# 3     A811680  2020-01-07T16:42:00.000  2020-01-07T16:42:00.000
# 4     A811677  2020-01-07T15:36:00.000  2020-01-07T15:36:00.000
# ..        ...                      ...                      ...
# 995   A806091  2019-10-05T13:38:00.000  2019-10-05T13:38:00.000
# 996   A806408  2019-10-10T13:58:00.000  2019-10-10T13:58:00.000
# 997   A806101  2019-10-05T15:00:00.000  2019-10-05T15:00:00.000
# 998   A806149  2019-10-06T13:24:00.000  2019-10-06T13:24:00.000
# 999   A800139  2019-07-16T18:38:00.000  2019-07-16T18:38:00.000
#
#                                     found_location intake_type  \
# 0       Cameron And Camino La Costa in Austin (TX)       Stray
# 1          2953 Bridekirk Drive in Round Rock (TX)       Stray
# 2             14908 Shell Hill Cove in Travis (TX)       Stray
# 3             14908 Shell Hill Cove in Travis (TX)       Stray
# 4          2953 Bridekirk Drive in Round Rock (TX)       Stray
# ..                                             ...         ...
# 995  Lexington Drive And Highway 290 in Manor (TX)       Stray
# 996   Walnut Avenue And 17Th Street in Austin (TX)       Stray
# 997  6101 Aac Highland Campus Drive in Austin (TX)       Stray
# 998                6608 Branrust Dr in Austin (TX)       Stray
# 999             5313 Atascosa Drive in Austin (TX)       Stray
#
#     intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0             Normal         Dog     Intact Male        6 months
# 1             Normal         Dog     Intact Male        3 months
# 2             Normal         Dog     Intact Male         2 years
# 3             Normal         Dog     Intact Male         2 years
# 4             Normal         Dog     Intact Male         3 years
# ..               ...         ...             ...             ...
# 995           Normal         Dog     Intact Male        8 months
# 996           Normal         Dog     Intact Male        7 months
# 997           Normal         Dog     Intact Male        2 months
# 998           Normal         Dog     Intact Male         2 years
# 999           Normal         Dog     Intact Male         1 month
#
#                                       breed              color      name
# 0                    Labrador Retriever Mix          Brown/Tan       NaN
# 1                  Maltese/Miniature Poodle        Black/White       NaN
# 2                 Rottweiler/Great Pyrenees         Brown/Gray       NaN
# 3                                Rottweiler        Black/Brown       NaN
# 4                  Maltese/Miniature Poodle        White/Black       NaN
# ..                                      ...                ...       ...
# 995               Australian Cattle Dog Mix         Gray/Black     *Dali
# 996                                  Beagle           Tricolor       NaN
# 997           Dachshund/Chihuahua Shorthair                Red       NaN
# 998  Basset Hound/American Pit Bull Terrier  Brown Tiger/White  *Bingley
# 999                      Chihuahua Longhair        Black/Brown  Iron Man
#
# [1000 rows x 12 columns]
